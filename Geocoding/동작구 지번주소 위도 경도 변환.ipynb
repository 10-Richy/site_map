# %%
import pandas as pd
df = pd.read_csv('C:\py_temp\Richy\민간\미변경\동작구 민간 공사장 데이터.csv',encoding='cp949')
df.head()

#df크기확인
df.shape

#주소데이터 전처리 함수
def get_addrs(x):
    x1 = x.split(' ')
    return " ".join(x1[2:4])
    
# 주소 전처리
df['지번주소'] = df['대지위치'].apply(get_addrs)
df
# Out:
#     연번 건축구분                        대지위치 지목  대지면적(㎡)  건축면적(㎡)    연면적(㎡)  \
# 0    1  대수선        서울특별시 동작구 대방동 403-11  대   759.09   410.99  2,794.37
# 1    2   증축         서울특별시 동작구 노량진동 28-6  대      145   135.21    715.71
# 2    3   신축    서울특별시 동작구 흑석동 186-4 외1필지  대    643.8   346.30  1,632.99
# 3    4   신축       서울특별시 동작구 상도동 279-266  대      264   157.74    527.61
# 4    5   신축  서울특별시 동작구 상도동 244-192 외1필지  대      252   150.84    582.41
# 5    6  대수선        서울특별시 동작구 사당동 139-53  대      119    71.35    209.24
# 6    7   신축         서울특별시 동작구 상도동 252-3  대    200.9   119.62     432.3
# 7    8   신축       서울특별시 동작구 상도동 299-102  대      165    98.84    397.86
# 8    9   신축       서울특별시 동작구 흑석동 186-165  대      200   119.26    440.89
# 9   10   신축           서울특별시 동작구 본동 51-8  대    186.9   105.66     277.8
# 10  11   신축        서울특별시 동작구 대방동 393-86  대    167.1    83.40    434.44
# 11  12   신축    서울특별시 동작구 사당동 182-3 외2필지  대   525.33   163.71  1,379.22
# 12  13  대수선         서울특별시 동작구 노량진동 54-8  대      231   128.54    891.66
# 13  14  대수선           서울특별시 동작구 대방동 520  대  9,547.3     1.00   1,491.5
# 14  15   신축        서울특별시 동작구 사당동 435-37  대      136    81.20    270.14
# 15  16   신축        서울특별시 동작구 대방동 386-20  대    265.1   146.87    562.11
# 16  17   신축    서울특별시 동작구 상도동 55-98 외1필지  대    165.2    98.64    404.48
# 17  18   신축       서울특별시 동작구 상도동 256-181  대      165    98.30    292.81
# 18  19   증축        서울특별시 동작구 상도동 235-30  대      169   101.20    436.67
# 19  20   신축        서울특별시 동작구 사당동 279-16  대      116    69.60    169.36
# 20  21   신축        서울특별시 동작구 상도1동 449-4  대    336.2   169.82    773.74
#
#     증축연면적(㎡)   건폐율(%)    용적률(%)  ... 최대지상층수 최대지하층수 동수        주용도  \
# 0        NaN  54.1425  284.6803  ...      7    1.0  1     교육연구시설
# 1        NaN  93.2500  403.0800  ...      5    1.0  1  제1종근린생활시설
# 2        NaN  53.7900  189.8600  ...      6    1.0  2       공동주택
# 3        NaN  59.7500  199.8500  ...      5    0.0  1       공동주택
# 4        NaN  59.8600  183.0400  ...      4    1.0  1       단독주택
# 5        NaN  59.9600  175.8300  ...      4    NaN  1  제2종근린생활시설
# 6        NaN  59.5400  165.5700  ...      4    1.0  1       단독주택
# 7        NaN  59.9030  191.4200  ...      4    1.0  1       단독주택
# 8        NaN  59.6300  160.8200  ...      4    1.0  1       단독주택
# 9        NaN  56.5300  148.6400  ...      5    0.0  1       공동주택
# 10       NaN  49.9100  198.6200  ...      5    1.0  1       단독주택
# 11       NaN  31.1600  249.3300  ...     10    1.0  1       업무시설
# 12       NaN  55.6450  294.9004  ...      6    1.0  1  제2종근린생활시설
# 13       NaN   1.0000    1.0000  ...      0    3.0  1       수련시설
# 14       NaN  59.7100  198.6300  ...      4    0.0  1       단독주택
# 15       NaN  55.4000  199.8300  ...      5    0.0  1       단독주택
# 16       NaN  59.7100  196.7600  ...      4    1.0  1       단독주택
# 17       NaN  59.5800  177.4600  ...      5    0.0  1       공동주택
# 18     39.62  59.8800  198.5000  ...      4    1.0  1       단독주택
# 19       NaN  60.0000  146.0000  ...      4    0.0  1       단독주택
# 20       NaN  50.5100  188.2300  ...      6    1.0  1       공동주택
#
#                            부속용도  총주차대수   세대수    호수  가구수         지번주소
# 0           교육연구및복지시설,제1종근린생활시설    NaN   NaN   NaN  NaN   대방동 403-11
# 1               근생 및 위락시설(무도학원)    NaN   NaN   NaN  NaN    노량진동 28-6
# 2               도시형생활주택(단지형다세대)   18.0  36.0   NaN  NaN    흑석동 186-4
# 3                         다세대주택    8.0  10.0   NaN  NaN  상도동 279-266
# 4                       근생및다중주택    4.0   NaN   NaN  1.0  상도동 244-192
# 5                           NaN    1.0   NaN   NaN  NaN   사당동 139-53
# 6                       근생및다중주택    4.0   NaN  20.0  1.0    상도동 252-3
# 7                       근생및다중주택    3.0   NaN   NaN  1.0  상도동 299-102
# 8                 다중주택 및 근린생활시설    0.0   NaN   3.0  1.0  흑석동 186-165
# 9          도시형생활주택(단지형다세대:12세대)    6.0  12.0   NaN  NaN      본동 51-8
# 10                         다중주택    3.0   NaN   5.0  1.0   대방동 393-86
# 11               오피스텔 및 도시형생활주택   16.0  16.0   8.0  NaN    사당동 182-3
# 12                           의원    NaN   NaN   NaN  NaN    노량진동 54-8
# 13                      청소년수련시설    6.0   NaN   NaN  NaN      대방동 520
# 14         다중주택, 제2종근린생활시설(사무소)    2.0   NaN   NaN  1.0   사당동 435-37
# 15                         다중주택    4.0   NaN   7.0  1.0   대방동 386-20
# 16  다중주택 및 근린생활시설(종교집회장, 휴게음식점)    3.0   NaN   NaN  1.0    상도동 55-98
# 17     [다세대주택] 및 제2종근린생활시설[사무소]    4.0   6.0   1.0  NaN  상도동 256-181
# 18                근린생활시설및 다가구주택    3.0   NaN   NaN  7.0   상도동 235-30
# 19                        다가구주택    2.0   NaN   NaN  3.0   사당동 279-16
# 20                     단지형다세대주택    9.0  14.0   NaN  NaN   상도1동 449-4
#
# [21 rows x 23 columns]

# %%
from geopy.geocoders import Nominatim
geo_local = Nominatim(user_agent='South Korea')

#위도 반환 함수
def geocoding_lat(address):
    try:
        geo = geo_local.geocode(address)
        return geo.latitude

    except:
        return 0
        
#경도 반환 함수
def geocoding_lon(address):
    try:
        geo = geo_local.geocode(address)
        return geo.longitude

    except:
        return 0

# 변환
df['위도'] = df['지번주소'].apply(geocoding_lat)
df['경도'] = df['지번주소'].apply(geocoding_lon)
df
# Out:
#     연번 건축구분                        대지위치 지목  대지면적(㎡)  건축면적(㎡)    연면적(㎡)  \
# 0    1  대수선        서울특별시 동작구 대방동 403-11  대   759.09   410.99  2,794.37
# 1    2   증축         서울특별시 동작구 노량진동 28-6  대      145   135.21    715.71
# 2    3   신축    서울특별시 동작구 흑석동 186-4 외1필지  대    643.8   346.30  1,632.99
# 3    4   신축       서울특별시 동작구 상도동 279-266  대      264   157.74    527.61
# 4    5   신축  서울특별시 동작구 상도동 244-192 외1필지  대      252   150.84    582.41
# 5    6  대수선        서울특별시 동작구 사당동 139-53  대      119    71.35    209.24
# 6    7   신축         서울특별시 동작구 상도동 252-3  대    200.9   119.62     432.3
# 7    8   신축       서울특별시 동작구 상도동 299-102  대      165    98.84    397.86
# 8    9   신축       서울특별시 동작구 흑석동 186-165  대      200   119.26    440.89
# 9   10   신축           서울특별시 동작구 본동 51-8  대    186.9   105.66     277.8
# 10  11   신축        서울특별시 동작구 대방동 393-86  대    167.1    83.40    434.44
# 11  12   신축    서울특별시 동작구 사당동 182-3 외2필지  대   525.33   163.71  1,379.22
# 12  13  대수선         서울특별시 동작구 노량진동 54-8  대      231   128.54    891.66
# 13  14  대수선           서울특별시 동작구 대방동 520  대  9,547.3     1.00   1,491.5
# 14  15   신축        서울특별시 동작구 사당동 435-37  대      136    81.20    270.14
# 15  16   신축        서울특별시 동작구 대방동 386-20  대    265.1   146.87    562.11
# 16  17   신축    서울특별시 동작구 상도동 55-98 외1필지  대    165.2    98.64    404.48
# 17  18   신축       서울특별시 동작구 상도동 256-181  대      165    98.30    292.81
# 18  19   증축        서울특별시 동작구 상도동 235-30  대      169   101.20    436.67
# 19  20   신축        서울특별시 동작구 사당동 279-16  대      116    69.60    169.36
# 20  21   신축        서울특별시 동작구 상도1동 449-4  대    336.2   169.82    773.74
#
#     증축연면적(㎡)   건폐율(%)    용적률(%)  ... 동수        주용도  \
# 0        NaN  54.1425  284.6803  ...  1     교육연구시설
# 1        NaN  93.2500  403.0800  ...  1  제1종근린생활시설
# 2        NaN  53.7900  189.8600  ...  2       공동주택
# 3        NaN  59.7500  199.8500  ...  1       공동주택
# 4        NaN  59.8600  183.0400  ...  1       단독주택
# 5        NaN  59.9600  175.8300  ...  1  제2종근린생활시설
# 6        NaN  59.5400  165.5700  ...  1       단독주택
# 7        NaN  59.9030  191.4200  ...  1       단독주택
# 8        NaN  59.6300  160.8200  ...  1       단독주택
# 9        NaN  56.5300  148.6400  ...  1       공동주택
# 10       NaN  49.9100  198.6200  ...  1       단독주택
# 11       NaN  31.1600  249.3300  ...  1       업무시설
# 12       NaN  55.6450  294.9004  ...  1  제2종근린생활시설
# 13       NaN   1.0000    1.0000  ...  1       수련시설
# 14       NaN  59.7100  198.6300  ...  1       단독주택
# 15       NaN  55.4000  199.8300  ...  1       단독주택
# 16       NaN  59.7100  196.7600  ...  1       단독주택
# 17       NaN  59.5800  177.4600  ...  1       공동주택
# 18     39.62  59.8800  198.5000  ...  1       단독주택
# 19       NaN  60.0000  146.0000  ...  1       단독주택
# 20       NaN  50.5100  188.2300  ...  1       공동주택
#
#                            부속용도  총주차대수   세대수    호수  가구수         지번주소  \
# 0           교육연구및복지시설,제1종근린생활시설    NaN   NaN   NaN  NaN   대방동 403-11
# 1               근생 및 위락시설(무도학원)    NaN   NaN   NaN  NaN    노량진동 28-6
# 2               도시형생활주택(단지형다세대)   18.0  36.0   NaN  NaN    흑석동 186-4
# 3                         다세대주택    8.0  10.0   NaN  NaN  상도동 279-266
# 4                       근생및다중주택    4.0   NaN   NaN  1.0  상도동 244-192
# 5                           NaN    1.0   NaN   NaN  NaN   사당동 139-53
# 6                       근생및다중주택    4.0   NaN  20.0  1.0    상도동 252-3
# 7                       근생및다중주택    3.0   NaN   NaN  1.0  상도동 299-102
# 8                 다중주택 및 근린생활시설    0.0   NaN   3.0  1.0  흑석동 186-165
# 9          도시형생활주택(단지형다세대:12세대)    6.0  12.0   NaN  NaN      본동 51-8
# 10                         다중주택    3.0   NaN   5.0  1.0   대방동 393-86
# 11               오피스텔 및 도시형생활주택   16.0  16.0   8.0  NaN    사당동 182-3
# 12                           의원    NaN   NaN   NaN  NaN    노량진동 54-8
# 13                      청소년수련시설    6.0   NaN   NaN  NaN      대방동 520
# 14         다중주택, 제2종근린생활시설(사무소)    2.0   NaN   NaN  1.0   사당동 435-37
# 15                         다중주택    4.0   NaN   7.0  1.0   대방동 386-20
# 16  다중주택 및 근린생활시설(종교집회장, 휴게음식점)    3.0   NaN   NaN  1.0    상도동 55-98
# 17     [다세대주택] 및 제2종근린생활시설[사무소]    4.0   6.0   1.0  NaN  상도동 256-181
# 18                근린생활시설및 다가구주택    3.0   NaN   NaN  7.0   상도동 235-30
# 19                        다가구주택    2.0   NaN   NaN  3.0   사당동 279-16
# 20                     단지형다세대주택    9.0  14.0   NaN  NaN   상도1동 449-4
#
#            위도          경도
# 0   37.507073  126.928034
# 1   37.511010  126.941463
# 2   36.266303  127.346314
# 3    0.000000    0.000000
# 4    0.000000    0.000000
# 5   37.485696  126.972352
# 6   36.015280  129.355190
# 7   37.498816  126.944104
# 8    0.000000    0.000000
# 9   37.327347  127.160235
# 10  37.507073  126.928034
# 11  37.485696  126.972352
# 12  37.511010  126.941463
# 13  37.507073  126.928034
# 14  37.485696  126.972352
# 15  37.507073  126.928034
# 16  37.498816  126.944104
# 17   0.000000    0.000000
# 18  37.498816  126.944104
# 19  37.485696  126.972352
# 20  37.499931  126.952190
#
# [21 rows x 25 columns]

# %%
#위치 정보를 제대로 불러오지 못한 부분 지번주소로 불러와 대체하기
#0값을 가지는 행 번호 추출하여 리스트 생성
nulls = df[df['위도'] == 0]
null_index = list(nulls.index)
null_index

#해당 index 부분만 지번번호 사용하여 주소정보 재추출
for i in null_index:
    df['위도'][i] = geocoding_lat(df['지번주소'][i])
    df['경도'][i] = geocoding_lon(df['지번주소'][i])
    
df[df['위도'] == 0]

#csv저장
df.to_csv('C:\py_temp\Richy\동작구geopy_address.csv',encoding='cp949',index=False)
# Out:
# C:\Users\leesy\AppData\Local\Temp\ipykernel_22264\3841290784.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['위도'][i] = geocoding_lat(df['지번주소'][i])
# C:\Users\leesy\AppData\Local\Temp\ipykernel_22264\3841290784.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['경도'][i] = geocoding_lon(df['지번주소'][i])
