# %%
import pandas as pd
df = pd.read_csv('C:\py_temp\Richy\민간\미변경\서울특별시 서대문구_공사장 현황_20221114.csv',encoding='cp949')
df.head()

#df크기확인
df.shape

#주소데이터 전처리 함수
def get_addrs(x):
    x1 = x.split(' ')
    return " ".join(x1[2:4])
    
# 주소 전처리
df['지번주소'] = df['대지위치'].apply(get_addrs)
df
# Out:
#     건축구분                        대지위치 지목  대지면적(제곱미터)  건축면적(제곱미터)  연면적(제곱미터)  \
# 0     신축        서울특별시 서대문구 홍은동 396-1  대      239.30      119.15     687.96
# 1     신축         서울특별시 서대문구 창천동 62-5  대      236.70      137.50     938.90
# 2     신축  서울특별시 서대문구 홍제동 330-33 외1필지  대      251.80      147.66    1187.74
# 3     신축        서울특별시 서대문구 연희동 188-1  대      317.70      210.37    1004.45
# 4     신축       서울특별시 서대문구 창천동 504-12  대      216.78      119.56     433.49
# ..   ...                         ... ..         ...         ...        ...
# 177   신축  서울특별시 서대문구 대현동 56-100 외3필지  대      262.20      174.30    1742.77
# 178   신축      서울특별시 서대문구 홍은동 265-311  대      271.00      161.74     693.88
# 179   신축        서울특별시 서대문구 대신동 124-8  대      277.00      138.28     632.98
# 180   신축         서울특별시 서대문구 연희동 92-3  대      248.30      123.37     345.65
# 181   신축         서울특별시 서대문구 신촌동 27-1  전      347.00      103.46     583.35
#
#             허가일  최대지상층수  최대지하층수        주용도                 부속용도         지번주소
# 0    2022-11-07       6       1       공동주택      도시형생활주택(단지형다세대)    홍은동 396-1
# 1    2022-11-01       8       1  제2종근린생활시설                  NaN     창천동 62-5
# 2    2022-10-25      10       1       업무시설  사무소 및 근린생활시설, 다세대주택   홍제동 330-33
# 3    2022-10-19       7       1  제2종근린생활시설                  사무소    연희동 188-1
# 4    2022-10-18       5       0  제2종근린생활시설                 단독주택   창천동 504-12
# ..          ...     ...     ...        ...                  ...          ...
# 177  2021-01-22      10       1       업무시설          오피스텔/근린생활시설   대현동 56-100
# 178  2021-01-21       4       1       공동주택                다세대주택  홍은동 265-311
# 179  2021-01-15       5       0       단독주택     제2종근린생활시설및 다가구주택    대신동 124-8
# 180  2021-01-15       2       1  제1종근린생활시설  제1종근린생활시설(소매점),단독주택     연희동 92-3
# 181  2021-01-06       3       1       단독주택                  NaN     신촌동 27-1
#
# [182 rows x 12 columns]

# %%
from geopy.geocoders import Nominatim
geo_local = Nominatim(user_agent='South Korea')

#위도 반환 함수
def geocoding_lat(address):
    try:
        geo = geo_local.geocode(address)
        return geo.latitude

    except:
        return 0
        
#경도 반환 함수
def geocoding_lon(address):
    try:
        geo = geo_local.geocode(address)
        return geo.longitude

    except:
        return 0

# 변환
df['위도'] = df['지번주소'].apply(geocoding_lat)
df['경도'] = df['지번주소'].apply(geocoding_lon)
df

# %%
#위치 정보를 제대로 불러오지 못한 부분 지번주소로 불러와 대체하기
#0값을 가지는 행 번호 추출하여 리스트 생성
nulls = df[df['위도'] == 0]
null_index = list(nulls.index)
null_index

#해당 index 부분만 지번번호 사용하여 주소정보 재추출
for i in null_index:
    df['위도'][i] = geocoding_lat(df['지번주소'][i])
    df['경도'][i] = geocoding_lon(df['지번주소'][i])
    
df[df['위도'] == 0]

#csv저장
df.to_csv('C:\py_temp\Richy\서대문구geopy_address.csv',encoding='cp949',index=False)
# Out:
# C:\Users\leesy\AppData\Local\Temp\ipykernel_20736\134081453.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['위도'][i] = geocoding_lat(df['지번주소'][i])
# C:\Users\leesy\AppData\Local\Temp\ipykernel_20736\134081453.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['경도'][i] = geocoding_lon(df['지번주소'][i])
